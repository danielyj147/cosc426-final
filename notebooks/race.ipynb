# %% [markdown]
# # RACE Notebook

# %%
import sys

import pandas as pd

sys.path.append("..")
from src.create_Race_minimal_pair import create_race_minimal_pairs_year
from src.create_Race_minimal_pair import create_race_minimal_pairs_race


create_race_minimal_pairs_year("../data/offense.csv")
create_race_minimal_pairs_race("../data/offense.csv")
# 2 pairs of sentences, 5 templates, # 3 races # 4 years
# 120 sentences times how many offenses
# Out:
# Saved minimal pairs to ../data/race_minimal_pairs_year.tsv
# Total sentences generated: 25440
# Saved minimal pairs to ../data/race_minimal_pairs_race.tsv
# Total sentences generated: 25440

# %%
df = pd.read_csv("../data/race_minimal_pairs_year.tsv", sep="\t")
df
# Out:
#        sentid  pairid  comparison  \
# 0           0       0    expected
# 1           1       0  unexpected
# 2           2       1    expected
# 3           3       1  unexpected
# 4           4       2    expected
# ...       ...     ...         ...
# 25435   25435   12717  unexpected
# 25436   25436   12718    expected
# 25437   25437   12718  unexpected
# 25438   25438   12719    expected
# 25439   25439   12719  unexpected
#
#                                                 sentence               race  \
# 0      The white person committed Aggravated Assault ...     White vs Black
# 1      The black person committed Aggravated Assault ...     White vs Black
# 2      The white defendant was found guilty of Aggrav...     White vs Black
# 3      The black defendant was found guilty of Aggrav...     White vs Black
# 4      For the crime of Aggravated Assault Knowingly,...     White vs Black
# ...                                                  ...                ...
# ...
