# %% [markdown]
# # Age Group VS Sentence

# %%
import os
import sys
import pandas as pd

sys.path.append("..")
from src.create_agegroup_minimal_pair import create_age_minimal_pairs_age
from src.create_agegroup_minimal_pair import create_age_minimal_pairs_year

create_age_minimal_pairs_age("../data/offense.csv")
create_age_minimal_pairs_year("../data/offense.csv")

# 2 pairs of sentences, 5 templates,
# 8 age groups
# 4 years
# Out:
# Saved age-group minimal pairs (AGE ROI) to ../data/age_minimal_pairs_age.tsv
# Total sentences generated: 237440
# Saved age-group minimal pairs (YEAR ROI) to ../data/age_minimal_pairs_year.tsv
# Total sentences generated: 237440

# %%
age = pd.read_csv("../data/age_minimal_pairs_age.tsv", sep="\t")
year = pd.read_csv("../data/age_minimal_pairs_year.tsv", sep="\t")

# %%
display(age.head())
display(year.head())
# Out:
#    sentid  pairid  comparison  \
# 0       0       0    expected
# 1       1       0  unexpected
# 2       2       1    expected
# 3       3       1  unexpected
# 4       4       2    expected
#
#                                             sentence        age_pair  \
# 0  The person who committed Aggravated Assault Kn...  22-30 vs 61-70
# 1  The person who committed Aggravated Assault Kn...  22-30 vs 61-70
# 2  The defendant was found guilty of Aggravated A...  22-30 vs 61-70
# 3  The defendant was found guilty of Aggravated A...  22-30 vs 61-70
# 4  The individual sentenced to 0 years for Aggrav...  22-30 vs 61-70
#
#   age_group  years  ROI  template_id
# 0     22-30      0   12            1
# 1     61-70      0   12            1
# 2     22-30      0   15            2
# 3     61-70      0   15            2
# 4     22-30      0   11            3
#    sentid  pairid  comparison  \
# 0       0       0    expected
# 1       1       0  unexpected
# 2       2       1    expected
# ...
