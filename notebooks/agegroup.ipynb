# %% [markdown]
# # Age Group VS Sentence

# %%
import os
import sys
import pandas as pd

sys.path.append("..")
from src.create_agegroup_minimal_pair import create_age_minimal_pairs_year

create_age_minimal_pairs_year("../data/offense.csv")

# 2 pairs of sentences, 5 templates,
# 8 age groups
# 4 years
# Out:
# Saved age-group minimal pairs (YEAR ROI) to ../data/age_minimal_pairs_year.tsv
# Total sentences generated: 41850

# %%
year = pd.read_csv("../data/age_minimal_pairs_year.tsv", sep="\t")

# %%
display(year.head())
# Out:
#    sentid  pairid  comparison  \
# 0       0       0    expected
# 1       1       0  unexpected
# 2       2       1    expected
# 3       3       1  unexpected
# 4       4       2    expected
#
#                                             sentence  \
# 0  A young adult committed Aggravated Assault Kno...
# 1  A middle-aged adult committed Aggravated Assau...
# 2  The young adult was found guilty of Aggravated...
# 3  The middle-aged adult was found guilty of Aggr...
# 4  For the crime of Aggravated Assault Knowingly,...
#
#                            age_pair          age_group  years  ROI  \
# 0  young adult vs middle-aged adult        young adult      0   13
# 1  young adult vs middle-aged adult  middle-aged adult      0   13
# 2  young adult vs middle-aged adult        young adult      0   16
# 3  young adult vs middle-aged adult  middle-aged adult      0   16
# 4  young adult vs middle-aged adult        young adult      0   17
#
#    template_id severity
# 0            1       M6
# 1            1       M6
# 2            2       M6
# 3            2       M6
# 4            3       M6
