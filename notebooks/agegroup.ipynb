# %% [markdown]
# # Age Group VS Sentence

# %%
import os
import sys
import pandas as pd

sys.path.append("..")
from src.create_agegroup_minimal_pair import create_age_minimal_pairs_year

create_age_minimal_pairs_year("../data/offense.csv")

# 2 pairs of sentences, 5 templates,
# 8 age groups
# 4 years
# Out:
# Saved age-group minimal pairs (YEAR ROI) to ../data/age_minimal_pairs_year_int.tsv
# Total sentences generated: 12555

# %%
year = pd.read_csv("../data/age_minimal_pairs_year_int.tsv", sep="\t")

# %%
display(year.head())
# Out:
#    sentid  pairid  comparison  \
# 0       0       0           0
# 1       1       0           1
# 2       2       0           2
# 3       3       1           0
# 4       4       1           1
#
#                                             sentence          age_group  \
# 0  A young adult committed Aggravated Assault Kno...        young adult
# 1  A middle-aged adult committed Aggravated Assau...  middle-aged adult
# 2  A older adult committed Aggravated Assault Kno...        older adult
# 3  The young adult was found guilty of Aggravated...        young adult
# 4  The middle-aged adult was found guilty of Aggr...  middle-aged adult
#
#    years  ROI  template_id severity
# 0      2   13            1       M6
# 1      2   13            1       M6
# 2      2   13            1       M6
# 3      2   16            2       M6
# 4      2   16            2       M6
