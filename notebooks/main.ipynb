# %% [markdown]
# # COSC426 Final Project

# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# For color coding
RED = "\033[31m"
GREEN = "\033[92m"
BLUE = "\033[94m"
END = "\033[0m"

# %%
print("=" * 40)
print(f"{BLUE}This is how you do it{END}")
print("-" * 40)
print("1. We got this: 0.43")
print("2. Let's go: 0.90")
print("=" * 40)
# Out:
# ...
# This is how you do it
# ----------------------------------------
# 1. We got this: 0.43
# 2. Let's go: 0.90
# ...
